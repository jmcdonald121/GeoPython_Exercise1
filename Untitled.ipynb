# %%
ice_cream_rating = 10
sleeping_rating = 7
first_name = input('First Name')
last_name = input('Last Name')
my_name = first_name + " "+last_name
print('My name is ', my_name)
# Out:
# First Name Jim
# Last Name McDonald
# My name is  Jim McDonald

# %%
happiness_rating = (ice_cream_rating + sleeping_rating)/2
print('Happiness Rating = ', happiness_rating)
# Out:
# Happiness Rating =  8.5

# %%
print("Ice Cream Type", type(ice_cream_rating))
print('First Name Type', type(first_name))
print("Happiness Rating Type", type(happiness_rating))
# Out:
# Ice Cream Type <class 'int'>
# First Name Type <class 'str'>
# Happiness Rating Type <class 'float'>

# %% [markdown]
# print("Ice Cream Type", type(ice_cream_rating))
# print('First Name Type', type(first_name))
# print("Happiness Rating Type", type(happiness_rating))

# %%
print("My name is ", first_name, ' and I give eating ice cream a score of ', ice_cream_rating, ' out of 10!')
print("I am ", my_name, " and my sleeping enjoyment rating is ", sleeping_rating,'/10!')
print('Based on the factors above, my happiness rating is ', happiness_rating, 'out of 10, or ', 10*happiness_rating, '%')
# Out:
# My name is  Jim  and I give eating ice cream a score of  10  out of 10!
# I am  Jim McDonald  and my sleeping enjoyment rating is  7 /10!
# Based on the factors above, my happiness rating is  8.5 out of 10, or  85.0 %
